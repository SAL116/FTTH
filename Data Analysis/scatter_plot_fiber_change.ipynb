# %%
import pandas as pd
data = pd.read_csv('final.csv')

# %%
import numpy as np

# %%
temp = pd.read_csv('all_states3.csv')
temp.head()
# Out:
#    COUNTYFP10  up18_fiber  up18_cable  up18_DSL  up18_total  down14_fiber  \
# 0           1       438.0      1281.0     677.0      2424.0           0.0
# 1           3      9105.0      3366.0   13025.0     16531.0        8639.0
# 2           5        35.0       449.0     485.0      1006.0           4.0
# 3           7        80.0         2.0     492.0       502.0           0.0
# 4           9       230.0       788.0    1045.0      2268.0           0.0
#
#    down14_cable  down14_DSL  down14_total  up15_fiber  ...  up17_DSL  \
# 0        1328.0       753.0        2084.0         2.0  ...     655.0
# 1        2879.0     12844.0       15729.0      8648.0  ...   12974.0
# 2         274.0       573.0         851.0         0.0  ...     474.0
# 3           0.0       502.0         502.0         0.0  ...     464.0
# 4         939.0      1330.0        2139.0         0.0  ...    1070.0
#
#    up17_total  down17_fiber  down17_cable  down17_DSL  down17_total     POP10  \
# ...

# %%
data=data.fillna(0)
data.head()
# Out:
#    Unnamed: 0  county  up18_fiber  up18_cable  up18_DSL  up18_total  \
# 0           0   24001         0.0         5.0       2.0         7.0
# 1           1   24003         4.0         2.0       1.0         9.0
# 2           2   24005         2.0         1.0       3.0        13.0
# 3           3   24009         0.0         1.0       2.0         4.0
# 4           4   24011         0.0         2.0       1.0         5.0
#
#    down14_fiber  down14_cable  down14_DSL  down14_total  ...  down17_cable  \
# 0           0.0           2.0         5.0           8.0  ...           4.0
# 1           2.0           2.0         6.0          10.0  ...           2.0
# 2           1.0           1.0         6.0          10.0  ...           1.0
# 3           0.0           1.0         3.0           4.0  ...           1.0
# 4           0.0           2.0         3.0           5.0  ...           2.0
#
#    down17_DSL  down17_total  2018_FIBER_YES  state_code     POP10  num_blocks  \
# ...

# %%
df = data[data.down14_fiber==0]
df.head()
# Out:
#    Unnamed: 0  county  up18_fiber  up18_cable  up18_DSL  up18_total  \
# 0           0   24001         0.0         5.0       2.0         7.0
# 3           3   24009         0.0         1.0       2.0         4.0
# 4           4   24011         0.0         2.0       1.0         5.0
# 6           6   24015         0.0         3.0       2.0         7.0
# 8           8   24019         1.0         3.0       1.0         6.0
#
#    down14_fiber  down14_cable  down14_DSL  down14_total  ...  down17_cable  \
# 0           0.0           2.0         5.0           8.0  ...           4.0
# 3           0.0           1.0         3.0           4.0  ...           1.0
# 4           0.0           2.0         3.0           5.0  ...           2.0
# 6           0.0           3.0         5.0           8.0  ...           4.0
# 8           0.0           1.0         2.0           3.0  ...           2.0
#
#    down17_DSL  down17_total  2018_FIBER_YES  state_code    POP10  num_blocks  \
# ...

# %%
df['change']=df.down15_fiber-df.down14_fiber
# Out:
# F:\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#    Unnamed: 0  county  up18_fiber  up18_cable  up18_DSL  up18_total  \
# 0           0   24001         0.0         5.0       2.0         7.0
# 3           3   24009         0.0         1.0       2.0         4.0
# 4           4   24011         0.0         2.0       1.0         5.0
# 6           6   24015         0.0         3.0       2.0         7.0
# 8           8   24019         1.0         3.0       1.0         6.0
#
#    down14_fiber  down14_cable  down14_DSL  down14_total  ...  down17_DSL  \
# 0           0.0           2.0         5.0           8.0  ...         6.0
# 3           0.0           1.0         3.0           4.0  ...         2.0
# 4           0.0           2.0         3.0           5.0  ...         2.0
# 6           0.0           3.0         5.0           8.0  ...         3.0
# 8           0.0           1.0         2.0           3.0  ...         1.0
#
#    down17_total  2018_FIBER_YES  state_code    POP10  num_blocks  StateAbbr  \
# ...

# %%
def f(x):
    if x>0:
        return 1
    else:
        return 0

# %%
df.change=df.change.apply(f)

# %%
df.head()
# Out:
#    Unnamed: 0  county  up18_fiber  up18_cable  up18_DSL  up18_total  \
# 0           0   24001         0.0         5.0       2.0         7.0
# 3           3   24009         0.0         1.0       2.0         4.0
# 4           4   24011         0.0         2.0       1.0         5.0
# 6           6   24015         0.0         3.0       2.0         7.0
# 8           8   24019         1.0         3.0       1.0         6.0
#
#    down14_fiber  down14_cable  down14_DSL  down14_total  ...  down17_DSL  \
# 0           0.0           2.0         5.0           8.0  ...         6.0
# 3           0.0           1.0         3.0           4.0  ...         2.0
# 4           0.0           2.0         3.0           5.0  ...         2.0
# 6           0.0           3.0         5.0           8.0  ...         3.0
# 8           0.0           1.0         2.0           3.0  ...         1.0
#
#    down17_total  2018_FIBER_YES  state_code    POP10  num_blocks  StateAbbr  \
# ...

# %%
x = df.down14_cable
y = np.floor(np.log(df.POP10.values))
df['providers14']=x
df['log_population14']=y
# Out:
# F:\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# F:\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
import matplotlib 
import matplotlib.pyplot as plt
import math
import numpy as np
# %matplotlib inline
x = np.ceil(df.down14_total)
y = np.floor(np.log(df.POP10.values))
df['providers14']=x
df['log_population14']=y

colors = np.where(df["change"]==1,'r','blue')
df.plot.scatter(x='providers14',y='log_population14',c=colors,alpha=1,figsize=(8,8))

plt.xlabel('Number of Providers')
plt.ylabel('Log number of Population')
plt.title('Fiber change 2014-2015')
red = matplotlib.lines.Line2D(range(1), range(1), color="white", marker='o', markerfacecolor="red")
blue = matplotlib.lines.Line2D(range(1), range(1), color="white", marker='o', markerfacecolor="blue")
handles = [red,blue]
labels = ['Using Fiber','No Fiber']
plt.legend(handles=handles, labels=labels,loc='lower right',bbox_to_anchor=(1.2, 0.5),bbox_transform=plt.gcf().transFigure)
plt.savefig("1.png", bbox_inches="tight")
plt.show()
# Out:
# F:\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# F:\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df2015 = data[data.down15_fiber==0]
df2015['change']=df2015.down16_fiber-df2015.down15_fiber
df2015.change=df2015.change.apply(f)
x = np.ceil(df2015.down15_total)
y = np.floor(np.log(df2015.POP10.values))
df2015['providers15']=x
df2015['log_population15']=y
colors = np.where(df2015["change"]==1,'r','blue')
df2015.plot.scatter(x='providers15',y='log_population15',c=colors,alpha=1,figsize=(8,8))

plt.xlabel('Number of Providers')
plt.ylabel('Log number of Population')
plt.title('Fiber change 2015-2016')
red = matplotlib.lines.Line2D(range(1), range(1), color="white", marker='o', markerfacecolor="red")
blue = matplotlib.lines.Line2D(range(1), range(1), color="white", marker='o', markerfacecolor="blue")
handles = [red,blue]
labels = ['Using Fiber','No Fiber']
plt.legend(handles=handles, labels=labels,loc='lower right',bbox_to_anchor=(1.2, 0.5),bbox_transform=plt.gcf().transFigure)
plt.savefig("2.png", bbox_inches="tight")
plt.show()
# Out:
# F:\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# F:\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# F:\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df2016 = data[data.down16_fiber==0]
df2016['change']=df2016.down17_fiber-df2016.down16_fiber
df2016.change=df2016.change.apply(f)
x = np.ceil(df2016.down16_total)
y = np.floor(np.log(df2016.POP10.values))
df2016['providers16']=x
df2016['log_population16']=y
colors = np.where(df2016["change"]==1,'r','blue')
df2016.plot.scatter(x='providers16',y='log_population16',c=colors,alpha=1,figsize=(8,8))

plt.xlabel('Number of Providers')
plt.ylabel('Log number of Population')
plt.title('Fiber change 2016-2017')
red = matplotlib.lines.Line2D(range(1), range(1), color="white", marker='o', markerfacecolor="red")
blue = matplotlib.lines.Line2D(range(1), range(1), color="white", marker='o', markerfacecolor="blue")
handles = [red,blue]
labels = ['Using Fiber','No Fiber']
plt.legend(handles=handles, labels=labels,loc='lower right',bbox_to_anchor=(1.2, 0.5),bbox_transform=plt.gcf().transFigure)
plt.savefig("3.png", bbox_inches="tight")
plt.show()
# Out:
# F:\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# F:\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# F:\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df2017 = data[data.down17_fiber==0]
df2017['change']=df2017.up18_fiber-df2017.down17_fiber
df2017.change=df2017.change.apply(f)
x = np.ceil(df2017.down17_total)
y = np.floor(np.log(df2017.POP10.values))
df2017['providers17']=x
df2017['log_population17']=y
colors = np.where(df2017["change"]==1,'r','blue')
df2017.plot.scatter(x='providers17',y='log_population17',c=colors,alpha=1,figsize=(8,8))

plt.xlabel('Number of Providers')
plt.ylabel('Log number of Population')
plt.title('Fiber change 2017-2018')
red = matplotlib.lines.Line2D(range(1), range(1), color="white", marker='o', markerfacecolor="red")
blue = matplotlib.lines.Line2D(range(1), range(1), color="white", marker='o', markerfacecolor="blue")
handles = [red,blue]
labels = ['Using Fiber','No Fiber']
plt.legend(handles=handles, labels=labels,loc='lower right',bbox_to_anchor=(1.2, 0.5),bbox_transform=plt.gcf().transFigure)
plt.savefig("4.png", bbox_inches="tight")
plt.show()
# Out:
# F:\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# F:\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# F:\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
ax = plt.subplot(2,2, 1)
colors = np.where(df["change"]==1,'r','blue')
df.plot.scatter(x='providers14',y='log_population14',c=colors,alpha=1,figsize=(10,10),ax=ax)
plt.xlabel('Number of Providers')
plt.ylabel('Log number of Population')
plt.title('Fiber change 2014-2015')

ax = plt.subplot(2,2, 2)
colors = np.where(df2015["change"]==1,'r','blue')
df2015.plot.scatter(x='providers15',y='log_population15',c=colors,alpha=1,figsize=(10,10),ax=ax)
plt.xlabel('Number of Providers')
plt.ylabel('Log number of Population')
plt.title('Fiber change 2015-2016')
red = matplotlib.lines.Line2D(range(1), range(1), color="white", marker='o', markerfacecolor="red")
blue = matplotlib.lines.Line2D(range(1), range(1), color="white", marker='o', markerfacecolor="blue")
handles = [red,blue]
labels = ['Using Fiber','No Fiber']
plt.legend(handles=handles, labels=labels,loc='lower right',bbox_to_anchor=(1.1, 0.53),bbox_transform=plt.gcf().transFigure)

plt.savefig("5.png", bbox_inches="tight")

# %%
ax = plt.subplot(2,2, 1)
colors = np.where(df2016["change"]==1,'r','blue')
df2016.plot.scatter(x='providers16',y='log_population16',c=colors,alpha=1,figsize=(10,10),ax=ax)
plt.xlabel('Number of Providers')
plt.ylabel('Log number of Population')
plt.title('Fiber change 2016-2017')

ax = plt.subplot(2,2, 2)
colors = np.where(df2017["change"]==1,'r','blue')
df2017.plot.scatter(x='providers17',y='log_population17',c=colors,alpha=1,figsize=(10,10),ax=ax)
plt.xlabel('Number of Providers')
plt.ylabel('Log number of Population')
plt.title('Fiber change 2017-2018')
red = matplotlib.lines.Line2D(range(1), range(1), color="white", marker='o', markerfacecolor="red")
blue = matplotlib.lines.Line2D(range(1), range(1), color="white", marker='o', markerfacecolor="blue")
handles = [red,blue]
labels = ['Using Fiber','No Fiber']
plt.legend(handles=handles, labels=labels,loc='lower right',bbox_to_anchor=(1.1, 0.53),bbox_transform=plt.gcf().transFigure)

plt.savefig("6.png", bbox_inches="tight")
